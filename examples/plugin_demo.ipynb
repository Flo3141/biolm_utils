# %% [markdown]
# # Plugin registry tutorial — quick demo
#
# This short notebook demonstrates a small thread-safe plugin registry API (compatible with the `biolm_utils.plugin_registry`) and shows how to register, apply, unregister, and restore plugins.
#
# ,
# ,
